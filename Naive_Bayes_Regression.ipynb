# %%
import pandas as pd

# %%
df = pd.read_csv("multinomial_nb_dataset.csv")

# %%
df
# Out:
#                                               Sentence       label
# 0                           goal win score player goal      sports
# 1    network computer algorithm algorithm cloud com...  technology
# 2        money free win buy free prize discount urgent        spam
# 3    cricket goal coach goal tournament goal match ...      sports
# 4    database database algorithm ML software algori...  technology
# ..                                                 ...         ...
# 295                network software cloud ML algorithm  technology
# 296  discount limited buy urgent discount urgent de...        spam
# 297        match coach score team football goal league      sports
# 298                hardware data database algorithm ML  technology
# 299           click free click limited urgent discount        spam
#
# [300 rows x 2 columns]

# %%
X = df.drop("label",axis=1)
y = df["Sentence"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
# from sklearn.naive_bayes import MultinomialNB

# model = MultinomialNB()

# model.fit(X_train,y_train)
# y_pred = model.predict(X_test)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Load data
df = pd.read_csv("multinomial_nb_dataset.csv")

X = df["Sentence"]
y = df["label"]

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# 🔥 MOST IMPORTANT STEP
vectorizer = CountVectorizer()

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Model
model = MultinomialNB()
model.fit(X_train_vec, y_train)

y_pred = model.predict(X_test_vec)

print("Model trained successfully")
# Out:
# Model trained successfully

# %%
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0
